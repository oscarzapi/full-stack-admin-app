# %%
# checking if path of system is equal to the environment path
import sys
sys.path[-1]
# Out:
# '/home/ubuntu/anaconda3/envs/mlops/lib/python3.8/site-packages'

# %%
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('mongodb+srv://oscar_zapi:mongodb_1111@cluster0.l8raroz.mongodb.net/?retryWrites=true&w=majority')

# %%
client.database_names()
# Out:
# /tmp/ipykernel_13578/3517499866.py:1: DeprecationWarning: database_names is deprecated. Use list_database_names instead.
#   client.database_names()
# ['test', 'admin', 'local']

# %%
db = client.test
db
# Out:
# Database(MongoClient(host=['ac-uqx8lso-shard-00-02.l8raroz.mongodb.net:27017', 'ac-uqx8lso-shard-00-01.l8raroz.mongodb.net:27017', 'ac-uqx8lso-shard-00-00.l8raroz.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-hr65yw-shard-0', ssl=True), 'test')

# %%
collection = db.productstats
collection
# Out:
# Collection(Database(MongoClient(host=['ac-uqx8lso-shard-00-02.l8raroz.mongodb.net:27017', 'ac-uqx8lso-shard-00-01.l8raroz.mongodb.net:27017', 'ac-uqx8lso-shard-00-00.l8raroz.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-hr65yw-shard-0', ssl=True), 'test'), 'productstats')

# %%
data = []
for document in collection.find({}):
    for key in document:
        if key in ['productId', 'dailyData']:
            data.append({key:document[key]})

# %%
data
# Out:
# [{'productId': '63701d24f03239c72c00018e'},
#  {'dailyData': [{'date': '2021-01-02',
#     'totalSales': 18,
#     'totalUnits': 3,
#     '_id': ObjectId('63b6c765d9f46447af85a621')},
#    {'date': '2021-01-03',
#     'totalSales': 33,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a622')},
#    {'date': '2021-01-04',
#     'totalSales': 5,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a623')},
#    {'date': '2021-01-05',
#     'totalSales': 40,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a624')},
#    {'date': '2021-01-06',
#     'totalSales': 83,
#     'totalUnits': 17,
#     '_id': ObjectId('63b6c765d9f46447af85a625')},
#    {'date': '2021-01-07',
#     'totalSales': 79,
#     'totalUnits': 26,
#     '_id': ObjectId('63b6c765d9f46447af85a626')},
#    {'date': '2021-01-08',
#     'totalSales': 98,
#     'totalUnits': 9,
#     '_id': ObjectId('63b6c765d9f46447af85a627')},
#    {'date': '2021-01-09',
#     'totalSales': 33,
#     'totalUnits': 25,
#     '_id': ObjectId('63b6c765d9f46447af85a628')},
#    {'date': '2021-01-10',
#     'totalSales': 32,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a629')},
#    {'date': '2021-01-11',
#     'totalSales': 65,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c765d9f46447af85a62a')},
#    {'date': '2021-01-12',
#     'totalSales': 71,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c765d9f46447af85a62b')},
#    {'date': '2021-01-13',
#     'totalSales': 66,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c765d9f46447af85a62c')},
#    {'date': '2021-01-14',
#     'totalSales': 3,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c765d9f46447af85a62d')},
#    {'date': '2021-01-15',
#     'totalSales': 64,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a62e')},
#    {'date': '2021-01-16',
#     'totalSales': 13,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c765d9f46447af85a62f')},
#    {'date': '2021-01-17',
#     'totalSales': 43,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c765d9f46447af85a630')},
#    {'date': '2021-01-18',
#     'totalSales': 5,
#     'totalUnits': 9,
#     '_id': ObjectId('63b6c765d9f46447af85a631')},
#    {'date': '2021-01-19',
#     'totalSales': 50,
#     'totalUnits': 42,
#     '_id': ObjectId('63b6c765d9f46447af85a632')},
#    {'date': '2021-01-20',
#     'totalSales': 42,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a633')},
#    {'date': '2021-01-21',
#     'totalSales': 32,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c765d9f46447af85a634')},
#    {'date': '2021-01-22',
#     'totalSales': 53,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c765d9f46447af85a635')},
#    {'date': '2021-01-23',
#     'totalSales': 98,
#     'totalUnits': 39,
#     '_id': ObjectId('63b6c765d9f46447af85a636')},
#    {'date': '2021-01-24',
#     'totalSales': 6,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a637')},
#    {'date': '2021-01-25',
#     'totalSales': 78,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c765d9f46447af85a638')},
#    {'date': '2021-01-26',
#     'totalSales': 71,
#     'totalUnits': 4,
#     '_id': ObjectId('63b6c765d9f46447af85a639')},
#    {'date': '2021-01-27',
#     'totalSales': 88,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c765d9f46447af85a63a')},
#    {'date': '2021-01-28',
#     'totalSales': 39,
#     'totalUnits': 47,
#     '_id': ObjectId('63b6c765d9f46447af85a63b')},
#    {'date': '2021-01-29',
#     'totalSales': 41,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a63c')},
#    {'date': '2021-01-30',
#     'totalSales': 31,
#     'totalUnits': 22,
#     '_id': ObjectId('63b6c765d9f46447af85a63d')},
#    {'date': '2021-01-31',
#     'totalSales': 37,
#     'totalUnits': 11,
#     '_id': ObjectId('63b6c765d9f46447af85a63e')},
#    {'date': '2021-02-01',
#     'totalSales': 15,
#     'totalUnits': 44,
#     '_id': ObjectId('63b6c765d9f46447af85a63f')},
#    {'date': '2021-02-02',
#     'totalSales': 36,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c765d9f46447af85a640')},
#    {'date': '2021-02-03',
#     'totalSales': 89,
#     'totalUnits': 11,
#     '_id': ObjectId('63b6c765d9f46447af85a641')},
#    {'date': '2021-02-04',
#     'totalSales': 10,
#     'totalUnits': 13,
#     '_id': ObjectId('63b6c765d9f46447af85a642')},
#    {'date': '2021-02-05',
#     'totalSales': 64,
#     'totalUnits': 31,
#     '_id': ObjectId('63b6c765d9f46447af85a643')},
#    {'date': '2021-02-06',
#     'totalSales': 91,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c765d9f46447af85a644')},
#    {'date': '2021-02-07',
#     'totalSales': 66,
#     'totalUnits': 1,
#     '_id': ObjectId('63b6c765d9f46447af85a645')},
#    {'date': '2021-02-08',
#     'totalSales': 71,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c765d9f46447af85a646')},
#    {'date': '2021-02-09',
#     'totalSales': 9,
#     'totalUnits': 8,
#     '_id': ObjectId('63b6c765d9f46447af85a647')},
#    {'date': '2021-02-10',
#     'totalSales': 78,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a648')},
#    {'date': '2021-02-11',
#     'totalSales': 51,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c765d9f46447af85a649')},
#    {'date': '2021-02-12',
#     'totalSales': 36,
#     'totalUnits': 23,
#     '_id': ObjectId('63b6c765d9f46447af85a64a')},
#    {'date': '2021-02-13',
#     'totalSales': 49,
#     'totalUnits': 13,
#     '_id': ObjectId('63b6c765d9f46447af85a64b')},
#    {'date': '2021-02-14',
#     'totalSales': 67,
#     'totalUnits': 3,
#     '_id': ObjectId('63b6c765d9f46447af85a64c')},
#    {'date': '2021-02-15',
#     'totalSales': 15,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c765d9f46447af85a64d')},
#    {'date': '2021-02-16',
#     'totalSales': 15,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c765d9f46447af85a64e')},
#    {'date': '2021-02-17',
#     'totalSales': 67,
#     'totalUnits': 12,
#     '_id': ObjectId('63b6c765d9f46447af85a64f')},
#    {'date': '2021-02-18',
#     'totalSales': 72,
#     'totalUnits': 31,
#     '_id': ObjectId('63b6c765d9f46447af85a650')},
#    {'date': '2021-02-19',
#     'totalSales': 52,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c765d9f46447af85a651')},
#    {'date': '2021-02-20',
#     'totalSales': 77,
#     'totalUnits': 40,
#     '_id': ObjectId('63b6c765d9f46447af85a652')},
#    {'date': '2021-02-21',
#     'totalSales': 81,
#     'totalUnits': 35,
#     '_id': ObjectId('63b6c765d9f46447af85a653')},
#    {'date': '2021-02-22',
#     'totalSales': 18,
#     'totalUnits': 35,
#     '_id': ObjectId('63b6c765d9f46447af85a654')},
#    {'date': '2021-02-23',
#     'totalSales': 27,
#     'totalUnits': 46,
#     '_id': ObjectId('63b6c765d9f46447af85a655')},
#    {'date': '2021-02-24',
#     'totalSales': 16,
#     'totalUnits': 45,
#     '_id': ObjectId('63b6c765d9f46447af85a656')},
#    {'date': '2021-02-25',
#     'totalSales': 40,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c765d9f46447af85a657')},
#    {'date': '2021-02-26',
#     'totalSales': 92,
#     'totalUnits': 31,
#     '_id': ObjectId('63b6c765d9f46447af85a658')},
#    {'date': '2021-02-27',
#     'totalSales': 90,
#     'totalUnits': 47,
#     '_id': ObjectId('63b6c765d9f46447af85a659')},
#    {'date': '2021-02-28',
#     'totalSales': 80,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c765d9f46447af85a65a')},
#    {'date': '2021-03-01',
#     'totalSales': 65,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c765d9f46447af85a65b')},
#    {'date': '2021-03-02',
#     'totalSales': 40,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c765d9f46447af85a65c')},
#    {'date': '2021-03-03',
#     'totalSales': 42,
#     'totalUnits': 14,
#     '_id': ObjectId('63b6c765d9f46447af85a65d')},
#    {'date': '2021-03-04',
#     'totalSales': 86,
#     'totalUnits': 28,
#     '_id': ObjectId('63b6c765d9f46447af85a65e')},
#    {'date': '2021-03-05',
#     'totalSales': 1,
#     'totalUnits': 40,
#     '_id': ObjectId('63b6c765d9f46447af85a65f')},
#    {'date': '2021-03-06',
#     'totalSales': 83,
#     'totalUnits': 8,
#     '_id': ObjectId('63b6c765d9f46447af85a660')},
#    {'date': '2021-03-07',
#     'totalSales': 17,
#     'totalUnits': 6,
#     '_id': ObjectId('63b6c765d9f46447af85a661')},
#    {'date': '2021-03-08',
#     'totalSales': 29,
#     'totalUnits': 8,
#     '_id': ObjectId('63b6c765d9f46447af85a662')},
#    {'date': '2021-03-09',
#     'totalSales': 73,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c765d9f46447af85a663')},
#    {'date': '2021-03-10',
#     'totalSales': 2,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a664')},
#    {'date': '2021-03-11',
#     'totalSales': 49,
#     'totalUnits': 17,
#     '_id': ObjectId('63b6c765d9f46447af85a665')},
#    {'date': '2021-03-12',
#     'totalSales': 71,
#     'totalUnits': 40,
#     '_id': ObjectId('63b6c765d9f46447af85a666')},
#    {'date': '2021-03-13',
#     'totalSales': 17,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c765d9f46447af85a667')},
#    {'date': '2021-03-14',
#     'totalSales': 13,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a668')},
#    {'date': '2021-03-15',
#     'totalSales': 35,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a669')},
#    {'date': '2021-03-16',
#     'totalSales': 94,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a66a')},
#    {'date': '2021-03-17',
#     'totalSales': 75,
#     'totalUnits': 33,
#     '_id': ObjectId('63b6c765d9f46447af85a66b')},
#    {'date': '2021-03-18',
#     'totalSales': 91,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c765d9f46447af85a66c')},
#    {'date': '2021-03-19',
#     'totalSales': 80,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c765d9f46447af85a66d')},
#    {'date': '2021-03-20',
#     'totalSales': 84,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a66e')},
#    {'date': '2021-03-21',
#     'totalSales': 10,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c765d9f46447af85a66f')},
#    {'date': '2021-03-22',
#     'totalSales': 80,
#     'totalUnits': 47,
#     '_id': ObjectId('63b6c765d9f46447af85a670')},
#    {'date': '2021-03-23',
#     'totalSales': 4,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c765d9f46447af85a671')},
#    {'date': '2021-03-24',
#     'totalSales': 51,
#     'totalUnits': 9,
#     '_id': ObjectId('63b6c765d9f46447af85a672')},
#    {'date': '2021-03-25',
#     'totalSales': 54,
#     'totalUnits': 23,
#     '_id': ObjectId('63b6c765d9f46447af85a673')},
#    {'date': '2021-03-26',
#     'totalSales': 53,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c765d9f46447af85a674')},
#    {'date': '2021-03-27',
#     'totalSales': 48,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a675')},
#    {'date': '2021-03-28',
#     'totalSales': 86,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a676')},
#    {'date': '2021-03-29',
#     'totalSales': 84,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c765d9f46447af85a677')},
#    {'date': '2021-03-30',
#     'totalSales': 32,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a678')},
#    {'date': '2021-03-31',
#     'totalSales': 82,
#     'totalUnits': 4,
#     '_id': ObjectId('63b6c765d9f46447af85a679')},
#    {'date': '2021-04-01',
#     'totalSales': 3,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a67a')},
#    {'date': '2021-04-02',
#     'totalSales': 12,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c765d9f46447af85a67b')},
#    {'date': '2021-04-03',
#     'totalSales': 62,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a67c')},
#    {'date': '2021-04-04',
#     'totalSales': 95,
#     'totalUnits': 12,
#     '_id': ObjectId('63b6c765d9f46447af85a67d')},
#    {'date': '2021-04-05',
#     'totalSales': 90,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c765d9f46447af85a67e')},
#    {'date': '2021-04-06',
#     'totalSales': 28,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a67f')},
#    {'date': '2021-04-07',
#     'totalSales': 31,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c765d9f46447af85a680')},
#    {'date': '2021-04-08',
#     'totalSales': 16,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a681')},
#    {'date': '2021-04-09',
#     'totalSales': 89,
#     'totalUnits': 9,
#     '_id': ObjectId('63b6c765d9f46447af85a682')},
#    {'date': '2021-04-10',
#     'totalSales': 56,
#     'totalUnits': 6,
#     '_id': ObjectId('63b6c765d9f46447af85a683')},
#    {'date': '2021-04-11',
#     'totalSales': 49,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c765d9f46447af85a684')},
#    {'date': '2021-04-12',
#     'totalSales': 30,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c765d9f46447af85a685')},
#    {'date': '2021-04-13',
#     'totalSales': 64,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c765d9f46447af85a686')},
#    {'date': '2021-04-14',
#     'totalSales': 73,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c765d9f46447af85a687')},
#    {'date': '2021-04-15',
#     'totalSales': 59,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a688')},
#    {'date': '2021-04-16',
#     'totalSales': 97,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c765d9f46447af85a689')},
#    {'date': '2021-04-17',
#     'totalSales': 69,
#     'totalUnits': 23,
#     '_id': ObjectId('63b6c765d9f46447af85a68a')},
#    {'date': '2021-04-18',
#     'totalSales': 27,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c765d9f46447af85a68b')},
#    {'date': '2021-04-19',
#     'totalSales': 16,
#     'totalUnits': 39,
#     '_id': ObjectId('63b6c765d9f46447af85a68c')},
#    {'date': '2021-04-20',
#     'totalSales': 38,
#     'totalUnits': 33,
#     '_id': ObjectId('63b6c765d9f46447af85a68d')},
#    {'date': '2021-04-21',
#     'totalSales': 15,
#     'totalUnits': 25,
#     '_id': ObjectId('63b6c765d9f46447af85a68e')},
#    {'date': '2021-04-22',
#     'totalSales': 23,
#     'totalUnits': 3,
#     '_id': ObjectId('63b6c765d9f46447af85a68f')},
#    {'date': '2021-04-23',
#     'totalSales': 13,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a690')},
#    {'date': '2021-04-24',
#     'totalSales': 97,
#     'totalUnits': 22,
#     '_id': ObjectId('63b6c765d9f46447af85a691')},
#    {'date': '2021-04-25',
#     'totalSales': 18,
#     'totalUnits': 44,
#     '_id': ObjectId('63b6c765d9f46447af85a692')},
#    {'date': '2021-04-26',
#     'totalSales': 4,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a693')},
#    {'date': '2021-04-27',
#     'totalSales': 19,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a694')},
#    {'date': '2021-04-28',
#     'totalSales': 96,
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c765d9f46447af85a695')},
#    {'date': '2021-04-29',
#     'totalSales': 58,
#     'totalUnits': 45,
#     '_id': ObjectId('63b6c765d9f46447af85a696')},
#    {'date': '2021-04-30',
#     'totalSales': 30,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c765d9f46447af85a697')},
#    {'date': '2021-05-01',
#     'totalSales': 30,
#     'totalUnits': 11,
#     '_id': ObjectId('63b6c765d9f46447af85a698')},
#    {'date': '2021-05-02',
#     'totalSales': 68,
#     'totalUnits': 25,
#     '_id': ObjectId('63b6c765d9f46447af85a699')},
#    {'date': '2021-05-03',
#     'totalSales': 42,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c765d9f46447af85a69a')},
#    {'date': '2021-05-04',
#     'totalSales': 69,
#     'totalUnits': 39,
#     '_id': ObjectId('63b6c765d9f46447af85a69b')},
#    {'date': '2021-05-05',
#     'totalSales': 63,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c765d9f46447af85a69c')},
#    {'date': '2021-05-06',
#     'totalSales': 39,
#     'totalUnits': 37,
#     '_id': ObjectId('63b6c765d9f46447af85a69d')},
#    {'date': '2021-05-07',
#     'totalSales': 47,
#     'totalUnits': 39,
#     '_id': ObjectId('63b6c765d9f46447af85a69e')},
#    {'date': '2021-05-08',
#     'totalSales': 28,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c765d9f46447af85a69f')},
#    {'date': '2021-05-09',
#     'totalSales': 68,
#     'totalUnits': 47,
#     '_id': ObjectId('63b6c765d9f46447af85a6a0')},
#    {'date': '2021-05-10',
#     'totalSales': 20,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c765d9f46447af85a6a1')},
#    {'date': '2021-05-11',
#     'totalSales': 43,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c765d9f46447af85a6a2')},
#    {'date': '2021-05-12',
#     'totalSales': 80,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a6a3')},
#    {'date': '2021-05-13',
#     'totalSales': 78,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a6a4')},
#    {'date': '2021-05-14',
#     'totalSales': 87,
#     'totalUnits': 21,
#     '_id': ObjectId('63b6c765d9f46447af85a6a5')},
#    {'date': '2021-05-15',
#     'totalSales': 86,
#     'totalUnits': 6,
#     '_id': ObjectId('63b6c765d9f46447af85a6a6')},
#    {'date': '2021-05-16',
#     'totalSales': 7,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c765d9f46447af85a6a7')},
#    {'date': '2021-05-17',
#     'totalSales': 47,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c765d9f46447af85a6a8')},
#    {'date': '2021-05-18',
#     'totalSales': 38,
#     'totalUnits': 27,
#     '_id': ObjectId('63b6c765d9f46447af85a6a9')},
#    {'date': '2021-05-19',
#     'totalSales': 79,
#     'totalUnits': 47,
#     '_id': ObjectId('63b6c765d9f46447af85a6aa')},
#    {'date': '2021-05-20',
#     'totalSales': 9,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c765d9f46447af85a6ab')},
#    {'date': '2021-05-21',
#     'totalSales': 15,
#     'totalUnits': 22,
#     '_id': ObjectId('63b6c765d9f46447af85a6ac')},
#    {'date': '2021-05-22',
#     'totalSales': 53,
#     'totalUnits': 3,
#     '_id': ObjectId('63b6c765d9f46447af85a6ad')},
#    {'date': '2021-05-23',
#     'totalSales': 49,
#     'totalUnits': 4,
#     '_id': ObjectId('63b6c765d9f46447af85a6ae')},
#    {'date': '2021-05-24',
#     'totalSales': 52,
#     'totalUnits': 13,
#     '_id': ObjectId('63b6c765d9f46447af85a6af')},
#    {'date': '2021-05-25',
#     'totalSales': 30,
#     'totalUnits': 44,
#     '_id': ObjectId('63b6c765d9f46447af85a6b0')},
#    {'date': '2021-05-26',
#     'totalSales': 7,
#     'totalUnits': 46,
#     '_id': ObjectId('63b6c765d9f46447af85a6b1')},
#    {'date': '2021-05-27',
#     'totalSales': 22,
#     'totalUnits': 14,
#     '_id': ObjectId('63b6c765d9f46447af85a6b2')},
#    {'date': '2021-05-28',
#     'totalSales': 53,
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c765d9f46447af85a6b3')},
#    {'date': '2021-05-29',
#     'totalSales': 77,
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c765d9f46447af85a6b4')},
#    {'date': '2021-05-30',
#     'totalSales': 67,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a6b5')},
#    {'date': '2021-05-31',
#     'totalSales': 88,
#     'totalUnits': 11,
#     '_id': ObjectId('63b6c765d9f46447af85a6b6')},
#    {'date': '2021-06-01',
#     'totalSales': 60,
#     'totalUnits': 22,
#     '_id': ObjectId('63b6c765d9f46447af85a6b7')},
#    {'date': '2021-06-02',
#     'totalSales': 88,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a6b8')},
#    {'date': '2021-06-03',
#     'totalSales': 86,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c765d9f46447af85a6b9')},
#    {'date': '2021-06-04',
#     'totalSales': 19,
#     'totalUnits': 26,
#     '_id': ObjectId('63b6c765d9f46447af85a6ba')},
#    {'date': '2021-06-05',
#     'totalSales': 12,
#     'totalUnits': 11,
#     '_id': ObjectId('63b6c765d9f46447af85a6bb')},
#    {'date': '2021-06-06',
#     'totalSales': 79,
#     'totalUnits': 4,
#     '_id': ObjectId('63b6c765d9f46447af85a6bc')},
#    {'date': '2021-06-07',
#     'totalSales': 54,
#     'totalUnits': 22,
#     '_id': ObjectId('63b6c765d9f46447af85a6bd')},
#    {'date': '2021-06-08',
#     'totalSales': 98,
#     'totalUnits': 33,
#     '_id': ObjectId('63b6c765d9f46447af85a6be')},
#    {'date': '2021-06-09',
#     'totalSales': 33,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a6bf')},
#    {'date': '2021-06-10',
#     'totalSales': 92,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c765d9f46447af85a6c0')},
#    {'date': '2021-06-11',
#     'totalSales': 14,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a6c1')},
#    {'date': '2021-06-12',
#     'totalSales': 35,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c765d9f46447af85a6c2')},
#    {'date': '2021-06-13',
#     'totalSales': 18,
#     'totalUnits': 4,
#     '_id': ObjectId('63b6c765d9f46447af85a6c3')},
#    {'date': '2021-06-14',
#     'totalSales': 91,
#     'totalUnits': 13,
#     '_id': ObjectId('63b6c765d9f46447af85a6c4')},
#    {'date': '2021-06-15',
#     'totalSales': 97,
#     'totalUnits': 46,
#     '_id': ObjectId('63b6c765d9f46447af85a6c5')},
#    {'date': '2021-06-16',
#     'totalSales': 90,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a6c6')},
#    {'date': '2021-06-17',
#     'totalSales': 96,
#     'totalUnits': 11,
#     '_id': ObjectId('63b6c765d9f46447af85a6c7')},
#    {'date': '2021-06-18',
#     'totalSales': 65,
#     'totalUnits': 25,
#     '_id': ObjectId('63b6c765d9f46447af85a6c8')},
#    {'date': '2021-06-19',
#     'totalSales': 73,
#     'totalUnits': 13,
#     '_id': ObjectId('63b6c765d9f46447af85a6c9')},
#    {'date': '2021-06-20',
#     'totalSales': 41,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c765d9f46447af85a6ca')},
#    {'date': '2021-06-21',
#     'totalSales': 36,
#     'totalUnits': 6,
#     '_id': ObjectId('63b6c765d9f46447af85a6cb')},
#    {'date': '2021-06-22',
#     'totalSales': 84,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c765d9f46447af85a6cc')},
#    {'date': '2021-06-23',
#     'totalSales': 42,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c765d9f46447af85a6cd')},
#    {'date': '2021-06-24',
#     'totalSales': 94,
#     'totalUnits': 33,
#     '_id': ObjectId('63b6c765d9f46447af85a6ce')},
#    {'date': '2021-06-25',
#     'totalSales': 6,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c765d9f46447af85a6cf')},
#    {'date': '2021-06-26',
#     'totalSales': 95,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a6d0')},
#    {'date': '2021-06-27',
#     'totalSales': 49,
#     'totalUnits': 4,
#     '_id': ObjectId('63b6c765d9f46447af85a6d1')},
#    {'date': '2021-06-28',
#     'totalSales': 70,
#     'totalUnits': 46,
#     '_id': ObjectId('63b6c765d9f46447af85a6d2')},
#    {'date': '2021-06-29',
#     'totalSales': 1,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a6d3')},
#    {'date': '2021-06-30',
#     'totalSales': 54,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c765d9f46447af85a6d4')},
#    {'date': '2021-07-01',
#     'totalSales': 100,
#     'totalUnits': 45,
#     '_id': ObjectId('63b6c765d9f46447af85a6d5')},
#    {'date': '2021-07-02',
#     'totalSales': 65,
#     'totalUnits': 27,
#     '_id': ObjectId('63b6c765d9f46447af85a6d6')},
#    {'date': '2021-07-03',
#     'totalSales': 66,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a6d7')},
#    {'date': '2021-07-04',
#     'totalSales': 9,
#     'totalUnits': 24,
#     '_id': ObjectId('63b6c765d9f46447af85a6d8')},
#    {'date': '2021-07-05',
#     'totalSales': 81,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c765d9f46447af85a6d9')},
#    {'date': '2021-07-06',
#     'totalSales': 5,
#     'totalUnits': 17,
#     '_id': ObjectId('63b6c765d9f46447af85a6da')},
#    {'date': '2021-07-07',
#     'totalSales': 77,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c765d9f46447af85a6db')},
#    {'date': '2021-07-08',
#     'totalSales': 88,
#     'totalUnits': 37,
#     '_id': ObjectId('63b6c765d9f46447af85a6dc')},
#    {'date': '2021-07-09',
#     'totalSales': 17,
#     'totalUnits': 37,
#     '_id': ObjectId('63b6c765d9f46447af85a6dd')},
#    {'date': '2021-07-10',
#     'totalSales': 35,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c765d9f46447af85a6de')},
#    {'date': '2021-07-11',
#     'totalSales': 32,
#     'totalUnits': 35,
#     '_id': ObjectId('63b6c765d9f46447af85a6df')},
#    {'date': '2021-07-12',
#     'totalSales': 13,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c765d9f46447af85a6e0')},
#    {'date': '2021-07-13',
#     'totalSales': 64,
#     'totalUnits': 23,
#     '_id': ObjectId('63b6c765d9f46447af85a6e1')},
#    {'date': '2021-07-14',
#     'totalSales': 76,
#     'totalUnits': 33,
#     '_id': ObjectId('63b6c765d9f46447af85a6e2')},
#    {'date': '2021-07-15',
#     'totalSales': 25,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c765d9f46447af85a6e3')},
#    {'date': '2021-07-16',
#     'totalSales': 72,
#     'totalUnits': 8,
#     '_id': ObjectId('63b6c765d9f46447af85a6e4')},
#    {'date': '2021-07-17',
#     'totalSales': 44,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c765d9f46447af85a6e5')},
#    {'date': '2021-07-18',
#     'totalSales': 87,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a6e6')},
#    {'date': '2021-07-19',
#     'totalSales': 30,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c765d9f46447af85a6e7')},
#    {'date': '2021-07-20',
#     'totalSales': 93,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c765d9f46447af85a6e8')},
#    {'date': '2021-07-21',
#     'totalSales': 72,
#     'totalUnits': 42,
#     '_id': ObjectId('63b6c765d9f46447af85a6e9')},
#    {'date': '2021-07-22',
#     'totalSales': 97,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a6ea')},
#    {'date': '2021-07-23',
#     'totalSales': 78,
#     'totalUnits': 42,
#     '_id': ObjectId('63b6c765d9f46447af85a6eb')},
#    {'date': '2021-07-24',
#     'totalSales': 6,
#     'totalUnits': 17,
#     '_id': ObjectId('63b6c765d9f46447af85a6ec')},
#    {'date': '2021-07-25',
#     'totalSales': 9,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c765d9f46447af85a6ed')},
#    {'date': '2021-07-26',
#     'totalSales': 5,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c765d9f46447af85a6ee')},
#    {'date': '2021-07-27',
#     'totalSales': 3,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c765d9f46447af85a6ef')},
#    {'date': '2021-07-28',
#     'totalSales': 18,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c765d9f46447af85a6f0')},
#    {'date': '2021-07-29',
#     'totalSales': 69,
#     'totalUnits': 33,
#     '_id': ObjectId('63b6c765d9f46447af85a6f1')},
#    {'date': '2021-07-30',
#     'totalSales': 6,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a6f2')},
#    {'date': '2021-07-31',
#     'totalSales': 54,
#     'totalUnits': 24,
#     '_id': ObjectId('63b6c765d9f46447af85a6f3')},
#    {'date': '2021-08-01',
#     'totalSales': 70,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a6f4')},
#    {'date': '2021-08-02',
#     'totalSales': 56,
#     'totalUnits': 12,
#     '_id': ObjectId('63b6c765d9f46447af85a6f5')},
#    {'date': '2021-08-03',
#     'totalSales': 90,
#     'totalUnits': 46,
#     '_id': ObjectId('63b6c765d9f46447af85a6f6')},
#    {'date': '2021-08-04',
#     'totalSales': 46,
#     'totalUnits': 39,
#     '_id': ObjectId('63b6c765d9f46447af85a6f7')},
#    {'date': '2021-08-05',
#     'totalSales': 49,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c765d9f46447af85a6f8')},
#    {'date': '2021-08-06',
#     'totalSales': 1,
#     'totalUnits': 37,
#     '_id': ObjectId('63b6c765d9f46447af85a6f9')},
#    {'date': '2021-08-07',
#     'totalSales': 51,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a6fa')},
#    {'date': '2021-08-08',
#     'totalSales': 20,
#     'totalUnits': 33,
#     '_id': ObjectId('63b6c765d9f46447af85a6fb')},
#    {'date': '2021-08-09',
#     'totalSales': 50,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a6fc')},
#    {'date': '2021-08-10',
#     'totalSales': 91,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a6fd')},
#    {'date': '2021-08-11',
#     'totalSales': 63,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c765d9f46447af85a6fe')},
#    {'date': '2021-08-12',
#     'totalSales': 28,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a6ff')},
#    {'date': '2021-08-13',
#     'totalSales': 93,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c765d9f46447af85a700')},
#    {'date': '2021-08-14',
#     'totalSales': 26,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c765d9f46447af85a701')},
#    {'date': '2021-08-15',
#     'totalSales': 33,
#     'totalUnits': 40,
#     '_id': ObjectId('63b6c765d9f46447af85a702')},
#    {'date': '2021-08-16',
#     'totalSales': 71,
#     'totalUnits': 11,
#     '_id': ObjectId('63b6c765d9f46447af85a703')},
#    {'date': '2021-08-17',
#     'totalSales': 40,
#     'totalUnits': 44,
#     '_id': ObjectId('63b6c765d9f46447af85a704')},
#    {'date': '2021-08-18',
#     'totalSales': 31,
#     'totalUnits': 6,
#     '_id': ObjectId('63b6c765d9f46447af85a705')},
#    {'date': '2021-08-19',
#     'totalSales': 29,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c765d9f46447af85a706')},
#    {'date': '2021-08-20',
#     'totalSales': 96,
#     'totalUnits': 47,
#     '_id': ObjectId('63b6c765d9f46447af85a707')},
#    {'date': '2021-08-21',
#     'totalSales': 27,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c765d9f46447af85a708')},
#    {'date': '2021-08-22',
#     'totalSales': 29,
#     'totalUnits': 31,
#     '_id': ObjectId('63b6c765d9f46447af85a709')},
#    {'date': '2021-08-23',
#     'totalSales': 31,
#     'totalUnits': 22,
#     '_id': ObjectId('63b6c765d9f46447af85a70a')},
#    {'date': '2021-08-24',
#     'totalSales': 16,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c765d9f46447af85a70b')},
#    {'date': '2021-08-25',
#     'totalSales': 33,
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c765d9f46447af85a70c')},
#    {'date': '2021-08-26',
#     'totalSales': 76,
#     'totalUnits': 28,
#     '_id': ObjectId('63b6c765d9f46447af85a70d')},
#    {'date': '2021-08-27',
#     'totalSales': 25,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c765d9f46447af85a70e')},
#    {'date': '2021-08-28',
#     'totalSales': 46,
#     'totalUnits': 18,
#     '_id': ObjectId('63b6c765d9f46447af85a70f')},
#    {'date': '2021-08-29',
#     'totalSales': 30,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c765d9f46447af85a710')},
#    {'date': '2021-08-30',
#     'totalSales': 61,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c765d9f46447af85a711')},
#    {'date': '2021-08-31',
#     'totalSales': 6,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c765d9f46447af85a712')},
#    {'date': '2021-09-01',
#     'totalSales': 36,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a713')},
#    {'date': '2021-09-02',
#     'totalSales': 75,
#     'totalUnits': 45,
#     '_id': ObjectId('63b6c765d9f46447af85a714')},
#    {'date': '2021-09-03',
#     'totalSales': 46,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c765d9f46447af85a715')},
#    {'date': '2021-09-04',
#     'totalSales': 2,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a716')},
#    {'date': '2021-09-05',
#     'totalSales': 73,
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c765d9f46447af85a717')},
#    {'date': '2021-09-06',
#     'totalSales': 96,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c765d9f46447af85a718')},
#    {'date': '2021-09-07',
#     'totalSales': 53,
#     'totalUnits': 4,
#     '_id': ObjectId('63b6c765d9f46447af85a719')},
#    {'date': '2021-09-08',
#     'totalSales': 51,
#     'totalUnits': 44,
#     '_id': ObjectId('63b6c765d9f46447af85a71a')},
#    {'date': '2021-09-09',
#     'totalSales': 40,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a71b')},
#    {'date': '2021-09-10',
#     'totalSales': 49,
#     'totalUnits': 28,
#     '_id': ObjectId('63b6c765d9f46447af85a71c')},
#    {'date': '2021-09-11',
#     'totalSales': 35,
#     'totalUnits': 8,
#     '_id': ObjectId('63b6c765d9f46447af85a71d')},
#    {'date': '2021-09-12',
#     'totalSales': 59,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a71e')},
#    {'date': '2021-09-13',
#     'totalSales': 20,
#     'totalUnits': 1,
#     '_id': ObjectId('63b6c765d9f46447af85a71f')},
#    {'date': '2021-09-14',
#     'totalSales': 90,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c765d9f46447af85a720')},
#    {'date': '2021-09-15',
#     'totalSales': 40,
#     'totalUnits': 42,
#     '_id': ObjectId('63b6c765d9f46447af85a721')},
#    {'date': '2021-09-16',
#     'totalSales': 24,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a722')},
#    {'date': '2021-09-17',
#     'totalSales': 42,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c765d9f46447af85a723')},
#    {'date': '2021-09-18',
#     'totalSales': 36,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a724')},
#    {'date': '2021-09-19',
#     'totalSales': 17,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c765d9f46447af85a725')},
#    {'date': '2021-09-20',
#     'totalSales': 15,
#     'totalUnits': 4,
#     '_id': ObjectId('63b6c765d9f46447af85a726')},
#    {'date': '2021-09-21',
#     'totalSales': 86,
#     'totalUnits': 47,
#     '_id': ObjectId('63b6c765d9f46447af85a727')},
#    {'date': '2021-09-22',
#     'totalSales': 52,
#     'totalUnits': 35,
#     '_id': ObjectId('63b6c765d9f46447af85a728')},
#    {'date': '2021-09-23',
#     'totalSales': 44,
#     'totalUnits': 14,
#     '_id': ObjectId('63b6c765d9f46447af85a729')},
#    {'date': '2021-09-24',
#     'totalSales': 60,
#     'totalUnits': 1,
#     '_id': ObjectId('63b6c765d9f46447af85a72a')},
#    {'date': '2021-09-25',
#     'totalSales': 3,
#     'totalUnits': 22,
#     '_id': ObjectId('63b6c765d9f46447af85a72b')},
#    {'date': '2021-09-26',
#     'totalSales': 31,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a72c')},
#    {'date': '2021-09-27',
#     'totalSales': 56,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c765d9f46447af85a72d')},
#    {'date': '2021-09-28',
#     'totalSales': 42,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c765d9f46447af85a72e')},
#    {'date': '2021-09-29',
#     'totalSales': 36,
#     'totalUnits': 6,
#     '_id': ObjectId('63b6c765d9f46447af85a72f')},
#    {'date': '2021-09-30',
#     'totalSales': 5,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c765d9f46447af85a730')},
#    {'date': '2021-10-01',
#     'totalSales': 68,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c765d9f46447af85a731')},
#    {'date': '2021-10-02',
#     'totalSales': 33,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c765d9f46447af85a732')},
#    {'date': '2021-10-03',
#     'totalSales': 99,
#     'totalUnits': 26,
#     '_id': ObjectId('63b6c765d9f46447af85a733')},
#    {'date': '2021-10-04',
#     'totalSales': 81,
#     'totalUnits': 35,
#     '_id': ObjectId('63b6c765d9f46447af85a734')},
#    {'date': '2021-10-05',
#     'totalSales': 27,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c765d9f46447af85a735')},
#    {'date': '2021-10-06',
#     'totalSales': 23,
#     'totalUnits': 45,
#     '_id': ObjectId('63b6c765d9f46447af85a736')},
#    {'date': '2021-10-07',
#     'totalSales': 40,
#     'totalUnits': 33,
#     '_id': ObjectId('63b6c765d9f46447af85a737')},
#    {'date': '2021-10-08',
#     'totalSales': 65,
#     'totalUnits': 21,
#     '_id': ObjectId('63b6c765d9f46447af85a738')},
#    {'date': '2021-10-09',
#     'totalSales': 44,
#     'totalUnits': 17,
#     '_id': ObjectId('63b6c765d9f46447af85a739')},
#    {'date': '2021-10-10',
#     'totalSales': 7,
#     'totalUnits': 17,
#     '_id': ObjectId('63b6c765d9f46447af85a73a')},
#    {'date': '2021-10-11',
#     'totalSales': 60,
#     'totalUnits': 12,
#     '_id': ObjectId('63b6c765d9f46447af85a73b')},
#    {'date': '2021-10-12',
#     'totalSales': 34,
#     'totalUnits': 18,
#     '_id': ObjectId('63b6c765d9f46447af85a73c')},
#    {'date': '2021-10-13',
#     'totalSales': 21,
#     'totalUnits': 12,
#     '_id': ObjectId('63b6c765d9f46447af85a73d')},
#    {'date': '2021-10-14',
#     'totalSales': 58,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a73e')},
#    {'date': '2021-10-15',
#     'totalSales': 21,
#     'totalUnits': 9,
#     '_id': ObjectId('63b6c765d9f46447af85a73f')},
#    {'date': '2021-10-16',
#     'totalSales': 41,
#     'totalUnits': 6,
#     '_id': ObjectId('63b6c765d9f46447af85a740')},
#    {'date': '2021-10-17',
#     'totalSales': 70,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a741')},
#    {'date': '2021-10-18',
#     'totalSales': 38,
#     'totalUnits': 31,
#     '_id': ObjectId('63b6c765d9f46447af85a742')},
#    {'date': '2021-10-19',
#     'totalSales': 69,
#     'totalUnits': 46,
#     '_id': ObjectId('63b6c765d9f46447af85a743')},
#    {'date': '2021-10-20',
#     'totalSales': 21,
#     'totalUnits': 37,
#     '_id': ObjectId('63b6c765d9f46447af85a744')},
#    {'date': '2021-10-21',
#     'totalSales': 40,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c765d9f46447af85a745')},
#    {'date': '2021-10-22',
#     'totalSales': 78,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a746')},
#    {'date': '2021-10-23',
#     'totalSales': 71,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a747')},
#    {'date': '2021-10-24',
#     'totalSales': 36,
#     'totalUnits': 18,
#     '_id': ObjectId('63b6c765d9f46447af85a748')},
#    {'date': '2021-10-25',
#     'totalSales': 65,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a749')},
#    {'date': '2021-10-26',
#     'totalSales': 52,
#     'totalUnits': 12,
#     '_id': ObjectId('63b6c765d9f46447af85a74a')},
#    {'date': '2021-10-27',
#     'totalSales': 67,
#     'totalUnits': 46,
#     '_id': ObjectId('63b6c765d9f46447af85a74b')},
#    {'date': '2021-10-28',
#     'totalSales': 25,
#     'totalUnits': 14,
#     '_id': ObjectId('63b6c765d9f46447af85a74c')},
#    {'date': '2021-10-29',
#     'totalSales': 5,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c765d9f46447af85a74d')},
#    {'date': '2021-10-30',
#     'totalSales': 6,
#     'totalUnits': 42,
#     '_id': ObjectId('63b6c765d9f46447af85a74e')},
#    {'date': '2021-10-31',
#     'totalSales': 14,
#     'totalUnits': 42,
#     '_id': ObjectId('63b6c765d9f46447af85a74f')},
#    {'date': '2021-11-01',
#     'totalSales': 74,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a750')},
#    {'date': '2021-11-02',
#     'totalSales': 92,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a751')},
#    {'date': '2021-11-03',
#     'totalSales': 39,
#     'totalUnits': 46,
#     '_id': ObjectId('63b6c765d9f46447af85a752')},
#    {'date': '2021-11-04',
#     'totalSales': 83,
#     'totalUnits': 13,
#     '_id': ObjectId('63b6c765d9f46447af85a753')},
#    {'date': '2021-11-05',
#     'totalSales': 10,
#     'totalUnits': 35,
#     '_id': ObjectId('63b6c765d9f46447af85a754')},
#    {'date': '2021-11-06',
#     'totalSales': 69,
#     'totalUnits': 26,
#     '_id': ObjectId('63b6c765d9f46447af85a755')},
#    {'date': '2021-11-07',
#     'totalSales': 21,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c765d9f46447af85a756')},
#    {'date': '2021-11-08',
#     'totalSales': 19,
#     'totalUnits': 39,
#     '_id': ObjectId('63b6c765d9f46447af85a757')},
#    {'date': '2021-11-09',
#     'totalSales': 27,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c765d9f46447af85a758')},
#    {'date': '2021-11-10',
#     'totalSales': 57,
#     'totalUnits': 9,
#     '_id': ObjectId('63b6c765d9f46447af85a759')},
#    {'date': '2021-11-11',
#     'totalSales': 98,
#     'totalUnits': 14,
#     '_id': ObjectId('63b6c765d9f46447af85a75a')},
#    {'date': '2021-11-12',
#     'totalSales': 73,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c765d9f46447af85a75b')},
#    {'date': '2021-11-13',
#     'totalSales': 37,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c765d9f46447af85a75c')},
#    {'date': '2021-11-14',
#     'totalSales': 94,
#     'totalUnits': 27,
#     '_id': ObjectId('63b6c765d9f46447af85a75d')},
#    {'date': '2021-11-15',
#     'totalSales': 32,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a75e')},
#    {'date': '2021-11-16',
#     'totalSales': 74,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a75f')},
#    {'date': '2021-11-17',
#     'totalSales': 26,
#     'totalUnits': 42,
#     '_id': ObjectId('63b6c765d9f46447af85a760')}]},
#  {'productId': '63701d24f03239c72c00018f'},
#  {'dailyData': [{'date': '2021-01-02',
#     'totalSales': 88,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c765d9f46447af85a76e')},
#    {'date': '2021-01-03',
#     'totalSales': 96,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c765d9f46447af85a76f')},
#    {'date': '2021-01-04',
#     'totalSales': 9,
#     'totalUnits': 26,
#     '_id': ObjectId('63b6c765d9f46447af85a770')},
#    {'date': '2021-01-05',
#     'totalSales': 79,
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c765d9f46447af85a771')},
#    {'date': '2021-01-06',
#     'totalSales': 27,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c765d9f46447af85a772')},
#    {'date': '2021-01-07',
#     'totalSales': 7,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c765d9f46447af85a773')},
#    {'date': '2021-01-08',
#     'totalSales': 4,
#     'totalUnits': 27,
#     '_id': ObjectId('63b6c765d9f46447af85a774')},
#    {'date': '2021-01-09',
#     'totalSales': 19,
#     'totalUnits': 12,
#     '_id': ObjectId('63b6c765d9f46447af85a775')},
#    {'date': '2021-01-10',
#     'totalSales': 20,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c765d9f46447af85a776')},
#    {'date': '2021-01-11',
#     'totalSales': 58,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c765d9f46447af85a777')},
#    {'date': '2021-01-12',
#     'totalSales': 54,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c765d9f46447af85a778')},
#    {'date': '2021-01-13',
#     'totalSales': 58,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a779')},
#    {'date': '2021-01-14',
#     'totalSales': 60,
#     'totalUnits': 14,
#     '_id': ObjectId('63b6c765d9f46447af85a77a')},
#    {'date': '2021-01-15',
#     'totalSales': 93,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a77b')},
#    {'date': '2021-01-16',
#     'totalSales': 60,
#     'totalUnits': 47,
#     '_id': ObjectId('63b6c765d9f46447af85a77c')},
#    {'date': '2021-01-17',
#     'totalSales': 97,
#     'totalUnits': 33,
#     '_id': ObjectId('63b6c765d9f46447af85a77d')},
#    {'date': '2021-01-18',
#     'totalSales': 28,
#     'totalUnits': 25,
#     '_id': ObjectId('63b6c765d9f46447af85a77e')},
#    {'date': '2021-01-19',
#     'totalSales': 13,
#     'totalUnits': 25,
#     '_id': ObjectId('63b6c765d9f46447af85a77f')},
#    {'date': '2021-01-20',
#     'totalSales': 59,
#     'totalUnits': 8,
#     '_id': ObjectId('63b6c765d9f46447af85a780')},
#    {'date': '2021-01-21',
#     'totalSales': 53,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c765d9f46447af85a781')},
#    {'date': '2021-01-22',
#     'totalSales': 64,
#     'totalUnits': 28,
#     '_id': ObjectId('63b6c765d9f46447af85a782')},
#    {'date': '2021-01-23',
#     'totalSales': 77,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c765d9f46447af85a783')},
#    {'date': '2021-01-24',
#     'totalSales': 71,
#     'totalUnits': 1,
#     '_id': ObjectId('63b6c765d9f46447af85a784')},
#    {'date': '2021-01-25',
#     'totalSales': 53,
#     'totalUnits': 17,
#     '_id': ObjectId('63b6c765d9f46447af85a785')},
#    {'date': '2021-01-26',
#     'totalSales': 40,
#     'totalUnits': 18,
#     '_id': ObjectId('63b6c765d9f46447af85a786')},
#    {'date': '2021-01-27',
#     'totalSales': 84,
#     'totalUnits': 25,
#     '_id': ObjectId('63b6c765d9f46447af85a787')},
#    {'date': '2021-01-28',
#     'totalSales': 26,
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c765d9f46447af85a788')},
#    {'date': '2021-01-29',
#     'totalSales': 85,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c765d9f46447af85a789')},
#    {'date': '2021-01-30',
#     'totalSales': 82,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c765d9f46447af85a78a')},
#    {'date': '2021-01-31',
#     'totalSales': 7,
#     'totalUnits': 6,
#     '_id': ObjectId('63b6c765d9f46447af85a78b')},
#    {'date': '2021-02-01',
#     'totalSales': 78,
#     'totalUnits': 14,
#     '_id': ObjectId('63b6c765d9f46447af85a78c')},
#    {'date': '2021-02-02',
#     'totalSales': 1,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c765d9f46447af85a78d')},
#    {'date': '2021-02-03',
#     'totalSales': 58,
#     'totalUnits': 24,
#     '_id': ObjectId('63b6c765d9f46447af85a78e')},
#    {'date': '2021-02-04',
#     'totalSales': 89,
#     'totalUnits': 45,
#     '_id': ObjectId('63b6c765d9f46447af85a78f')},
#    {'date': '2021-02-05',
#     'totalSales': 56,
#     'totalUnits': 44,
#     '_id': ObjectId('63b6c765d9f46447af85a790')},
#    {'date': '2021-02-06',
#     'totalSales': 33,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c765d9f46447af85a791')},
#    {'date': '2021-02-07',
#     'totalSales': 48,
#     'totalUnits': 26,
#     '_id': ObjectId('63b6c765d9f46447af85a792')},
#    {'date': '2021-02-08',
#     'totalSales': 33,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c765d9f46447af85a793')},
#    {'date': '2021-02-09',
#     'totalSales': 61,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c765d9f46447af85a794')},
#    {'date': '2021-02-10',
#     'totalSales': 3,
#     'totalUnits': 11,
#     '_id': ObjectId('63b6c765d9f46447af85a795')},
#    {'date': '2021-02-11',
#     'totalSales': 55,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c765d9f46447af85a796')},
#    {'date': '2021-02-12',
#     'totalSales': 86,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c765d9f46447af85a797')},
#    {'date': '2021-02-13',
#     'totalSales': 53,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c765d9f46447af85a798')},
#    {'date': '2021-02-14',
#     'totalSales': 78,
#     'totalUnits': 24,
#     '_id': ObjectId('63b6c765d9f46447af85a799')},
#    {'date': '2021-02-15',
#     'totalSales': 88,
#     'totalUnits': 37,
#     '_id': ObjectId('63b6c765d9f46447af85a79a')},
#    {'date': '2021-02-16',
#     'totalSales': 49,
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c765d9f46447af85a79b')},
#    {'date': '2021-02-17',
#     'totalSales': 90,
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c765d9f46447af85a79c')},
#    {'date': '2021-02-18',
#     'totalSales': 16,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a79d')},
#    {'date': '2021-02-19',
#     'totalSales': 49,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c765d9f46447af85a79e')},
#    {'date': '2021-02-20',
#     'totalSales': 68,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c765d9f46447af85a79f')},
#    {'date': '2021-02-21',
#     'totalSales': 35,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c765d9f46447af85a7a0')},
#    {'date': '2021-02-22',
#     'totalSales': 37,
#     'totalUnits': 37,
#     '_id': ObjectId('63b6c765d9f46447af85a7a1')},
#    {'date': '2021-02-23',
#     'totalSales': 85,
#     'totalUnits': 37,
#     '_id': ObjectId('63b6c765d9f46447af85a7a2')},
#    {'date': '2021-02-24',
#     'totalSales': 69,
#     'totalUnits': 39,
#     '_id': ObjectId('63b6c765d9f46447af85a7a3')},
#    {'date': '2021-02-25',
#     'totalSales': 5,
#     'totalUnits': 12,
#     '_id': ObjectId('63b6c765d9f46447af85a7a4')},
#    {'date': '2021-02-26',
#     'totalSales': 67,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c765d9f46447af85a7a5')},
#    {'date': '2021-02-27',
#     'totalSales': 95,
#     'totalUnits': 11,
#     '_id': ObjectId('63b6c765d9f46447af85a7a6')},
#    {'date': '2021-02-28',
#     'totalSales': 43,
#     'totalUnits': 13,
#     '_id': ObjectId('63b6c765d9f46447af85a7a7')},
#    {'date': '2021-03-01',
#     'totalSales': 87,
#     'totalUnits': 13,
#     '_id': ObjectId('63b6c765d9f46447af85a7a8')},
#    {'date': '2021-03-02',
#     'totalSales': 46,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c765d9f46447af85a7a9')},
#    {'date': '2021-03-03',
#     'totalSales': 96,
#     'totalUnits': 28,
#     '_id': ObjectId('63b6c765d9f46447af85a7aa')},
#    {'date': '2021-03-04',
#     'totalSales': 31,
#     'totalUnits': 23,
#     '_id': ObjectId('63b6c765d9f46447af85a7ab')},
#    {'date': '2021-03-05',
#     'totalSales': 91,
#     'totalUnits': 39,
#     '_id': ObjectId('63b6c765d9f46447af85a7ac')},
#    {'date': '2021-03-06',
#     'totalSales': 96,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c765d9f46447af85a7ad')},
#    {'date': '2021-03-07',
#     'totalSales': 55,
#     'totalUnits': 27,
#     '_id': ObjectId('63b6c765d9f46447af85a7ae')},
#    {'date': '2021-03-08',
#     'totalSales': 62,
#     'totalUnits': 31,
#     '_id': ObjectId('63b6c765d9f46447af85a7af')},
#    {'date': '2021-03-09',
#     'totalSales': 39,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c765d9f46447af85a7b0')},
#    {'date': '2021-03-10',
#     'totalSales': 62,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c765d9f46447af85a7b1')},
#    {'date': '2021-03-11',
#     'totalSales': 9,
#     'totalUnits': 18,
#     '_id': ObjectId('63b6c765d9f46447af85a7b2')},
#    {'date': '2021-03-12',
#     'totalSales': 21,
#     'totalUnits': 9,
#     '_id': ObjectId('63b6c765d9f46447af85a7b3')},
#    {'date': '2021-03-13',
#     'totalSales': 35,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c765d9f46447af85a7b4')},
#    {'date': '2021-03-14',
#     'totalSales': 68,
#     'totalUnits': 8,
#     '_id': ObjectId('63b6c765d9f46447af85a7b5')},
#    {'date': '2021-03-15',
#     'totalSales': 77,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a7b6')},
#    {'date': '2021-03-16',
#     'totalSales': 41,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c765d9f46447af85a7b7')},
#    {'date': '2021-03-17',
#     'totalSales': 67,
#     'totalUnits': 46,
#     '_id': ObjectId('63b6c765d9f46447af85a7b8')},
#    {'date': '2021-03-18',
#     'totalSales': 58,
#     'totalUnits': 46,
#     '_id': ObjectId('63b6c765d9f46447af85a7b9')},
#    {'date': '2021-03-19',
#     'totalSales': 19,
#     'totalUnits': 9,
#     '_id': ObjectId('63b6c765d9f46447af85a7ba')},
#    {'date': '2021-03-20',
#     'totalSales': 41,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c765d9f46447af85a7bb')},
#    {'date': '2021-03-21',
#     'totalSales': 78,
#     'totalUnits': 11,
#     '_id': ObjectId('63b6c765d9f46447af85a7bc')},
#    {'date': '2021-03-22',
#     'totalSales': 28,
#     'totalUnits': 35,
# ...
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c766d9f46447af85cc94')},
#    {'date': '2021-07-08',
#     'totalSales': 48,
#     'totalUnits': 17,
#     '_id': ObjectId('63b6c766d9f46447af85cc95')},
#    {'date': '2021-07-09',
#     'totalSales': 75,
#     'totalUnits': 46,
#     '_id': ObjectId('63b6c766d9f46447af85cc96')},
#    {'date': '2021-07-10',
#     'totalSales': 49,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c766d9f46447af85cc97')},
#    {'date': '2021-07-11',
#     'totalSales': 52,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c766d9f46447af85cc98')},
#    {'date': '2021-07-12',
#     'totalSales': 21,
#     'totalUnits': 17,
#     '_id': ObjectId('63b6c766d9f46447af85cc99')},
#    {'date': '2021-07-13',
#     'totalSales': 95,
#     'totalUnits': 14,
#     '_id': ObjectId('63b6c766d9f46447af85cc9a')},
#    {'date': '2021-07-14',
#     'totalSales': 5,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c766d9f46447af85cc9b')},
#    {'date': '2021-07-15',
#     'totalSales': 53,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c766d9f46447af85cc9c')},
#    {'date': '2021-07-16',
#     'totalSales': 46,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c766d9f46447af85cc9d')},
#    {'date': '2021-07-17',
#     'totalSales': 79,
#     'totalUnits': 24,
#     '_id': ObjectId('63b6c766d9f46447af85cc9e')},
#    {'date': '2021-07-18',
#     'totalSales': 72,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c766d9f46447af85cc9f')},
#    {'date': '2021-07-19',
#     'totalSales': 23,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c766d9f46447af85cca0')},
#    {'date': '2021-07-20',
#     'totalSales': 55,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c766d9f46447af85cca1')},
#    {'date': '2021-07-21',
#     'totalSales': 5,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c766d9f46447af85cca2')},
#    {'date': '2021-07-22',
#     'totalSales': 31,
#     'totalUnits': 35,
#     '_id': ObjectId('63b6c766d9f46447af85cca3')},
#    {'date': '2021-07-23',
#     'totalSales': 40,
#     'totalUnits': 31,
#     '_id': ObjectId('63b6c766d9f46447af85cca4')},
#    {'date': '2021-07-24',
#     'totalSales': 63,
#     'totalUnits': 13,
#     '_id': ObjectId('63b6c766d9f46447af85cca5')},
#    {'date': '2021-07-25',
#     'totalSales': 77,
#     'totalUnits': 6,
#     '_id': ObjectId('63b6c766d9f46447af85cca6')},
#    {'date': '2021-07-26',
#     'totalSales': 17,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c766d9f46447af85cca7')},
#    {'date': '2021-07-27',
#     'totalSales': 69,
#     'totalUnits': 45,
#     '_id': ObjectId('63b6c766d9f46447af85cca8')},
#    {'date': '2021-07-28',
#     'totalSales': 46,
#     'totalUnits': 40,
#     '_id': ObjectId('63b6c766d9f46447af85cca9')},
#    {'date': '2021-07-29',
#     'totalSales': 57,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c766d9f46447af85ccaa')},
#    {'date': '2021-07-30',
#     'totalSales': 23,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c766d9f46447af85ccab')},
#    {'date': '2021-07-31',
#     'totalSales': 31,
#     'totalUnits': 17,
#     '_id': ObjectId('63b6c766d9f46447af85ccac')},
#    {'date': '2021-08-01',
#     'totalSales': 45,
#     'totalUnits': 1,
#     '_id': ObjectId('63b6c766d9f46447af85ccad')},
#    {'date': '2021-08-02',
#     'totalSales': 33,
#     'totalUnits': 24,
#     '_id': ObjectId('63b6c766d9f46447af85ccae')},
#    {'date': '2021-08-03',
#     'totalSales': 65,
#     'totalUnits': 27,
#     '_id': ObjectId('63b6c766d9f46447af85ccaf')},
#    {'date': '2021-08-04',
#     'totalSales': 48,
#     'totalUnits': 22,
#     '_id': ObjectId('63b6c766d9f46447af85ccb0')},
#    {'date': '2021-08-05',
#     'totalSales': 77,
#     'totalUnits': 8,
#     '_id': ObjectId('63b6c766d9f46447af85ccb1')},
#    {'date': '2021-08-06',
#     'totalSales': 16,
#     'totalUnits': 3,
#     '_id': ObjectId('63b6c766d9f46447af85ccb2')},
#    {'date': '2021-08-07',
#     'totalSales': 55,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c766d9f46447af85ccb3')},
#    {'date': '2021-08-08',
#     'totalSales': 90,
#     'totalUnits': 42,
#     '_id': ObjectId('63b6c766d9f46447af85ccb4')},
#    {'date': '2021-08-09',
#     'totalSales': 3,
#     'totalUnits': 17,
#     '_id': ObjectId('63b6c766d9f46447af85ccb5')},
#    {'date': '2021-08-10',
#     'totalSales': 30,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c766d9f46447af85ccb6')},
#    {'date': '2021-08-11',
#     'totalSales': 1,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c766d9f46447af85ccb7')},
#    {'date': '2021-08-12',
#     'totalSales': 66,
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c766d9f46447af85ccb8')},
#    {'date': '2021-08-13',
#     'totalSales': 37,
#     'totalUnits': 14,
#     '_id': ObjectId('63b6c766d9f46447af85ccb9')},
#    {'date': '2021-08-14',
#     'totalSales': 84,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c766d9f46447af85ccba')},
#    {'date': '2021-08-15',
#     'totalSales': 86,
#     'totalUnits': 31,
#     '_id': ObjectId('63b6c766d9f46447af85ccbb')},
#    {'date': '2021-08-16',
#     'totalSales': 9,
#     'totalUnits': 45,
#     '_id': ObjectId('63b6c766d9f46447af85ccbc')},
#    {'date': '2021-08-17',
#     'totalSales': 96,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c766d9f46447af85ccbd')},
#    {'date': '2021-08-18',
#     'totalSales': 54,
#     'totalUnits': 37,
#     '_id': ObjectId('63b6c766d9f46447af85ccbe')},
#    {'date': '2021-08-19',
#     'totalSales': 32,
#     'totalUnits': 45,
#     '_id': ObjectId('63b6c766d9f46447af85ccbf')},
#    {'date': '2021-08-20',
#     'totalSales': 13,
#     'totalUnits': 39,
#     '_id': ObjectId('63b6c766d9f46447af85ccc0')},
#    {'date': '2021-08-21',
#     'totalSales': 88,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c766d9f46447af85ccc1')},
#    {'date': '2021-08-22',
#     'totalSales': 21,
#     'totalUnits': 21,
#     '_id': ObjectId('63b6c766d9f46447af85ccc2')},
#    {'date': '2021-08-23',
#     'totalSales': 100,
#     'totalUnits': 24,
#     '_id': ObjectId('63b6c766d9f46447af85ccc3')},
#    {'date': '2021-08-24',
#     'totalSales': 73,
#     'totalUnits': 24,
#     '_id': ObjectId('63b6c766d9f46447af85ccc4')},
#    {'date': '2021-08-25',
#     'totalSales': 62,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c766d9f46447af85ccc5')},
#    {'date': '2021-08-26',
#     'totalSales': 26,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c766d9f46447af85ccc6')},
#    {'date': '2021-08-27',
#     'totalSales': 42,
#     'totalUnits': 38,
#     '_id': ObjectId('63b6c766d9f46447af85ccc7')},
#    {'date': '2021-08-28',
#     'totalSales': 41,
#     'totalUnits': 9,
#     '_id': ObjectId('63b6c766d9f46447af85ccc8')},
#    {'date': '2021-08-29',
#     'totalSales': 70,
#     'totalUnits': 29,
#     '_id': ObjectId('63b6c766d9f46447af85ccc9')},
#    {'date': '2021-08-30',
#     'totalSales': 41,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c766d9f46447af85ccca')},
#    {'date': '2021-08-31',
#     'totalSales': 8,
#     'totalUnits': 45,
#     '_id': ObjectId('63b6c766d9f46447af85cccb')},
#    {'date': '2021-09-01',
#     'totalSales': 57,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c766d9f46447af85cccc')},
#    {'date': '2021-09-02',
#     'totalSales': 97,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c766d9f46447af85cccd')},
#    {'date': '2021-09-03',
#     'totalSales': 83,
#     'totalUnits': 12,
#     '_id': ObjectId('63b6c766d9f46447af85ccce')},
#    {'date': '2021-09-04',
#     'totalSales': 49,
#     'totalUnits': 4,
#     '_id': ObjectId('63b6c766d9f46447af85cccf')},
#    {'date': '2021-09-05',
#     'totalSales': 8,
#     'totalUnits': 18,
#     '_id': ObjectId('63b6c766d9f46447af85ccd0')},
#    {'date': '2021-09-06',
#     'totalSales': 75,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c766d9f46447af85ccd1')},
#    {'date': '2021-09-07',
#     'totalSales': 71,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c766d9f46447af85ccd2')},
#    {'date': '2021-09-08',
#     'totalSales': 27,
#     'totalUnits': 43,
#     '_id': ObjectId('63b6c766d9f46447af85ccd3')},
#    {'date': '2021-09-09',
#     'totalSales': 89,
#     'totalUnits': 37,
#     '_id': ObjectId('63b6c766d9f46447af85ccd4')},
#    {'date': '2021-09-10',
#     'totalSales': 39,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c766d9f46447af85ccd5')},
#    {'date': '2021-09-11',
#     'totalSales': 62,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c766d9f46447af85ccd6')},
#    {'date': '2021-09-12',
#     'totalSales': 14,
#     'totalUnits': 40,
#     '_id': ObjectId('63b6c766d9f46447af85ccd7')},
#    {'date': '2021-09-13',
#     'totalSales': 22,
#     'totalUnits': 18,
#     '_id': ObjectId('63b6c766d9f46447af85ccd8')},
#    {'date': '2021-09-14',
#     'totalSales': 29,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c766d9f46447af85ccd9')},
#    {'date': '2021-09-15',
#     'totalSales': 38,
#     'totalUnits': 18,
#     '_id': ObjectId('63b6c766d9f46447af85ccda')},
#    {'date': '2021-09-16',
#     'totalSales': 50,
#     'totalUnits': 21,
#     '_id': ObjectId('63b6c766d9f46447af85ccdb')},
#    {'date': '2021-09-17',
#     'totalSales': 79,
#     'totalUnits': 8,
#     '_id': ObjectId('63b6c766d9f46447af85ccdc')},
#    {'date': '2021-09-18',
#     'totalSales': 21,
#     'totalUnits': 39,
#     '_id': ObjectId('63b6c766d9f46447af85ccdd')},
#    {'date': '2021-09-19',
#     'totalSales': 22,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c766d9f46447af85ccde')},
#    {'date': '2021-09-20',
#     'totalSales': 26,
#     'totalUnits': 6,
#     '_id': ObjectId('63b6c766d9f46447af85ccdf')},
#    {'date': '2021-09-21',
#     'totalSales': 100,
#     'totalUnits': 2,
#     '_id': ObjectId('63b6c766d9f46447af85cce0')},
#    {'date': '2021-09-22',
#     'totalSales': 25,
#     'totalUnits': 47,
#     '_id': ObjectId('63b6c766d9f46447af85cce1')},
#    {'date': '2021-09-23',
#     'totalSales': 24,
#     'totalUnits': 8,
#     '_id': ObjectId('63b6c766d9f46447af85cce2')},
#    {'date': '2021-09-24',
#     'totalSales': 52,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c766d9f46447af85cce3')},
#    {'date': '2021-09-25',
#     'totalSales': 27,
#     'totalUnits': 14,
#     '_id': ObjectId('63b6c766d9f46447af85cce4')},
#    {'date': '2021-09-26',
#     'totalSales': 4,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c766d9f46447af85cce5')},
#    {'date': '2021-09-27',
#     'totalSales': 65,
#     'totalUnits': 26,
#     '_id': ObjectId('63b6c766d9f46447af85cce6')},
#    {'date': '2021-09-28',
#     'totalSales': 61,
#     'totalUnits': 41,
#     '_id': ObjectId('63b6c766d9f46447af85cce7')},
#    {'date': '2021-09-29',
#     'totalSales': 51,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c766d9f46447af85cce8')},
#    {'date': '2021-09-30',
#     'totalSales': 27,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c766d9f46447af85cce9')},
#    {'date': '2021-10-01',
#     'totalSales': 82,
#     'totalUnits': 9,
#     '_id': ObjectId('63b6c766d9f46447af85ccea')},
#    {'date': '2021-10-02',
#     'totalSales': 96,
#     'totalUnits': 22,
#     '_id': ObjectId('63b6c766d9f46447af85cceb')},
#    {'date': '2021-10-03',
#     'totalSales': 63,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c766d9f46447af85ccec')},
#    {'date': '2021-10-04',
#     'totalSales': 13,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c766d9f46447af85cced')},
#    {'date': '2021-10-05',
#     'totalSales': 8,
#     'totalUnits': 45,
#     '_id': ObjectId('63b6c766d9f46447af85ccee')},
#    {'date': '2021-10-06',
#     'totalSales': 14,
#     'totalUnits': 21,
#     '_id': ObjectId('63b6c766d9f46447af85ccef')},
#    {'date': '2021-10-07',
#     'totalSales': 12,
#     'totalUnits': 22,
#     '_id': ObjectId('63b6c766d9f46447af85ccf0')},
#    {'date': '2021-10-08',
#     'totalSales': 85,
#     'totalUnits': 10,
#     '_id': ObjectId('63b6c766d9f46447af85ccf1')},
#    {'date': '2021-10-09',
#     'totalSales': 88,
#     'totalUnits': 13,
#     '_id': ObjectId('63b6c766d9f46447af85ccf2')},
#    {'date': '2021-10-10',
#     'totalSales': 37,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c766d9f46447af85ccf3')},
#    {'date': '2021-10-11',
#     'totalSales': 28,
#     'totalUnits': 9,
#     '_id': ObjectId('63b6c766d9f46447af85ccf4')},
#    {'date': '2021-10-12',
#     'totalSales': 97,
#     'totalUnits': 32,
#     '_id': ObjectId('63b6c766d9f46447af85ccf5')},
#    {'date': '2021-10-13',
#     'totalSales': 96,
#     'totalUnits': 36,
#     '_id': ObjectId('63b6c766d9f46447af85ccf6')},
#    {'date': '2021-10-14',
#     'totalSales': 33,
#     'totalUnits': 47,
#     '_id': ObjectId('63b6c766d9f46447af85ccf7')},
#    {'date': '2021-10-15',
#     'totalSales': 92,
#     'totalUnits': 1,
#     '_id': ObjectId('63b6c766d9f46447af85ccf8')},
#    {'date': '2021-10-16',
#     'totalSales': 62,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c766d9f46447af85ccf9')},
#    {'date': '2021-10-17',
#     'totalSales': 48,
#     'totalUnits': 3,
#     '_id': ObjectId('63b6c766d9f46447af85ccfa')},
#    {'date': '2021-10-18',
#     'totalSales': 13,
#     'totalUnits': 28,
#     '_id': ObjectId('63b6c766d9f46447af85ccfb')},
#    {'date': '2021-10-19',
#     'totalSales': 67,
#     'totalUnits': 35,
#     '_id': ObjectId('63b6c766d9f46447af85ccfc')},
#    {'date': '2021-10-20',
#     'totalSales': 57,
#     'totalUnits': 15,
#     '_id': ObjectId('63b6c766d9f46447af85ccfd')},
#    {'date': '2021-10-21',
#     'totalSales': 29,
#     'totalUnits': 30,
#     '_id': ObjectId('63b6c766d9f46447af85ccfe')},
#    {'date': '2021-10-22',
#     'totalSales': 77,
#     'totalUnits': 16,
#     '_id': ObjectId('63b6c766d9f46447af85ccff')},
#    {'date': '2021-10-23',
#     'totalSales': 90,
#     'totalUnits': 4,
#     '_id': ObjectId('63b6c766d9f46447af85cd00')},
#    {'date': '2021-10-24',
#     'totalSales': 98,
#     'totalUnits': 24,
#     '_id': ObjectId('63b6c766d9f46447af85cd01')},
#    {'date': '2021-10-25',
#     'totalSales': 63,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c766d9f46447af85cd02')},
#    {'date': '2021-10-26',
#     'totalSales': 93,
#     'totalUnits': 34,
#     '_id': ObjectId('63b6c766d9f46447af85cd03')},
#    {'date': '2021-10-27',
#     'totalSales': 24,
#     'totalUnits': 27,
#     '_id': ObjectId('63b6c766d9f46447af85cd04')},
#    {'date': '2021-10-28',
#     'totalSales': 15,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c766d9f46447af85cd05')},
#    {'date': '2021-10-29',
#     'totalSales': 89,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c766d9f46447af85cd06')},
#    {'date': '2021-10-30',
#     'totalSales': 48,
#     'totalUnits': 50,
#     '_id': ObjectId('63b6c766d9f46447af85cd07')},
#    {'date': '2021-10-31',
#     'totalSales': 73,
#     'totalUnits': 49,
#     '_id': ObjectId('63b6c766d9f46447af85cd08')},
#    {'date': '2021-11-01',
#     'totalSales': 6,
#     'totalUnits': 25,
#     '_id': ObjectId('63b6c766d9f46447af85cd09')},
#    {'date': '2021-11-02',
#     'totalSales': 90,
#     'totalUnits': 37,
#     '_id': ObjectId('63b6c766d9f46447af85cd0a')},
#    {'date': '2021-11-03',
#     'totalSales': 96,
#     'totalUnits': 7,
#     '_id': ObjectId('63b6c766d9f46447af85cd0b')},
#    {'date': '2021-11-04',
#     'totalSales': 82,
#     'totalUnits': 28,
#     '_id': ObjectId('63b6c766d9f46447af85cd0c')},
#    {'date': '2021-11-05',
#     'totalSales': 82,
#     'totalUnits': 3,
#     '_id': ObjectId('63b6c766d9f46447af85cd0d')},
#    {'date': '2021-11-06',
#     'totalSales': 83,
#     'totalUnits': 35,
#     '_id': ObjectId('63b6c766d9f46447af85cd0e')},
#    {'date': '2021-11-07',
#     'totalSales': 11,
#     'totalUnits': 48,
#     '_id': ObjectId('63b6c766d9f46447af85cd0f')},
#    {'date': '2021-11-08',
#     'totalSales': 88,
#     'totalUnits': 18,
#     '_id': ObjectId('63b6c766d9f46447af85cd10')},
#    {'date': '2021-11-09',
#     'totalSales': 30,
#     'totalUnits': 20,
#     '_id': ObjectId('63b6c766d9f46447af85cd11')},
#    {'date': '2021-11-10',
#     'totalSales': 94,
#     'totalUnits': 24,
#     '_id': ObjectId('63b6c766d9f46447af85cd12')},
#    {'date': '2021-11-11',
#     'totalSales': 47,
#     'totalUnits': 19,
#     '_id': ObjectId('63b6c766d9f46447af85cd13')},
#    {'date': '2021-11-12',
#     'totalSales': 61,
#     'totalUnits': 31,
#     '_id': ObjectId('63b6c766d9f46447af85cd14')},
#    {'date': '2021-11-13',
#     'totalSales': 77,
#     'totalUnits': 12,
#     '_id': ObjectId('63b6c766d9f46447af85cd15')},
#    {'date': '2021-11-14',
#     'totalSales': 19,
#     'totalUnits': 27,
#     '_id': ObjectId('63b6c766d9f46447af85cd16')},
#    {'date': '2021-11-15',
#     'totalSales': 6,
#     'totalUnits': 28,
#     '_id': ObjectId('63b6c766d9f46447af85cd17')},
#    {'date': '2021-11-16',
#     'totalSales': 33,
#     'totalUnits': 5,
#     '_id': ObjectId('63b6c766d9f46447af85cd18')},
#    {'date': '2021-11-17',
#     'totalSales': 36,
#     'totalUnits': 22,
#     '_id': ObjectId('63b6c766d9f46447af85cd19')}]}]

# %%
import pandas as pd
for i in data:
    for key, values in i.items():
        if key == 'dailyData':
            print(values['date'])
            #values['date'] = pd.to_datetime(values['date'])

print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 2>()
#       3     for key, values in i.items():
#       4         if key == 'dailyData':
# ----> 5             values['date'] = pd.to_datetime(values['date'])
#       7 print(data)
#
# TypeError: list indices must be integers or slices, not str
